# %% [markdown]
# ## **이미지 데이터 구축 - 이미지 크롤링**
# 1. 링크를 통해 https://github.com/mtinet/googleImageDownloader
# - download_images.py
# - js_console.js
# 을 다운받고 코랩에 드래그 해서 업로드 해주세요.
#
# 2. 구글에서 원하는 이미지를 검색한 뒤 최대한 이미지가 많이 담겨올수있도록 스크롤을 아래로 내려서 이미지 수를 늘려줍니다.
#
# 3. 구글 이미지 검색에서 f12 를 눌러 console 창을 열어줍니다.
#    js_console.js 에 있는 코드를 복사하여 console창에 붙여줍니다.
#    그러면 url.txt 파일이 다운로드 됩니다. 이 파일을 코랩에 올려주세요.
#
# 4. 아래의 코드를 실행하여 이미지를 저장합니다.

# %% [markdown]
# # **구글 드라이브 가져오기**

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %% [markdown]
# # **url.txt파일을 통해 구글 드라이브에 이미지를 저장합니다**

# %%
# !python download_images.py -u url.txt -o "/content/gdrive/My Drive/Colab Notebooks/bollard" #경로
